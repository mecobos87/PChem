# %%
import pandas as pd
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure




new_df = pd.read_csv('Zach Diphenyl groups.csv')
new_df
# Out:
#         Wave1  Abs1    Wave2  Abs2    Wave3  Abs3
# 0     179.802 -1.52  179.802 -1.41  179.802 -1.42
# 1     180.182 -1.52  180.182 -1.41  180.182 -1.42
# 2     180.563 -1.52  180.563 -1.41  180.563 -1.42
# 3     180.943 -0.59  180.943 -0.64  180.943 -0.42
# 4     181.323  0.00  181.323  0.00  181.323  0.00
# ...       ...   ...      ...   ...      ...   ...
# 2043  874.673  0.01  874.673  0.01  874.673  0.03
# 2044  874.961  0.01  874.961  0.01  874.961  0.03
# 2045  875.249  0.01  875.249  0.01  875.249  0.04
# 2046  875.538  0.01  875.538  0.01  875.538  0.04
# 2047  875.826  0.01  875.826  0.01  875.826  0.04
#
# [2048 rows x 6 columns]

# %%
plt.figure(figsize= (50,15))

plt.title('UV-Vis Spectroscopy', fontdict = {'fontweight':'bold', 'fontsize': 18})

plt.plot(new_df.Wave1, new_df.Abs1, 'b.-', label = 'Butadiene')
plt.plot(new_df.Wave2, new_df.Abs2, 'g.-', label = 'Hexadiene')
plt.plot(new_df.Wave3, new_df.Abs3, 'r.-', label = 'Octadiene')
#plt.plot(gas.Year, gas.Canada, 'r^-', label = 'Canada')
#plt.plot(gas['Year'], gas['South Korea'], 'g.--', label = 'South Korea')
#plt.plot(gas.Year, gas.Mexico,'.-', label = 'Mexico')

# print(gas.Year[::3])

#####################################################################################################

# for country in gas:
#     if country != 'Year':
#         plt.plot(gas.Year, gas[country], marker = '.', label = country)

#####################################################################################################

# countries_to_see = ['USA', 'Canada', 'South Korea']

# for country in gas:
#     if country in countries_to_see:
#         plt.plot(gas.Year, gas[country], marker = '.', label = country)
        
#####################################################################################################





plt.xticks(new_df.Wave1[::25])

plt.xlabel('Wavelength')
plt.ylabel('Absorbance')

plt.legend()

# plt.savefig('Gas_price_figure.png', dpi = 300)

plt.show()
