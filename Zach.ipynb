# %%
import pandas as pd
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure




new_df = pd.read_csv('Zach Cyanine groups.csv')
new_df
# Out:
#         Wave1  Abs1    Wave2  Abs2    Wave3  Abs3
# 0     179.802 -1.79  179.802 -1.80  179.802 -1.70
# 1     180.182 -1.79  180.182 -1.80  180.182 -1.70
# 2     180.563 -1.79  180.563 -1.80  180.563 -1.70
# 3     180.943 -0.78  180.943 -0.69  180.943 -0.58
# 4     181.323  0.00  181.323  0.00  181.323  0.00
# ...       ...   ...      ...   ...      ...   ...
# 2057  874.673  0.03  874.673  0.06      NaN   NaN
# 2058  874.961  0.04  874.961  0.06      NaN   NaN
# 2059  875.249  0.04  875.249  0.06      NaN   NaN
# 2060  875.538  0.04  875.538  0.06      NaN   NaN
# 2061  875.826  0.04  875.826  0.06      NaN   NaN
#
# [2062 rows x 6 columns]

# %%
plt.figure(figsize= (35,15))

plt.title('UV-Vis Spectroscopy', fontdict = {'fontweight':'bold', 'fontsize': 18})

plt.plot(new_df.Wave1, new_df.Abs1, 'b.-', label = 'Cyanine')
plt.plot(new_df.Wave2, new_df.Abs2, 'g.-', label = 'Carbocyanine')
plt.plot(new_df.Wave3, new_df.Abs3, 'r.-', label = 'Dicarbocyanine')
#plt.plot(gas.Year, gas.Canada, 'r^-', label = 'Canada')
#plt.plot(gas['Year'], gas['South Korea'], 'g.--', label = 'South Korea')
#plt.plot(gas.Year, gas.Mexico,'.-', label = 'Mexico')

# print(gas.Year[::3])

#####################################################################################################

# for country in gas:
#     if country != 'Year':
#         plt.plot(gas.Year, gas[country], marker = '.', label = country)

#####################################################################################################

# countries_to_see = ['USA', 'Canada', 'South Korea']

# for country in gas:
#     if country in countries_to_see:
#         plt.plot(gas.Year, gas[country], marker = '.', label = country)
        
#####################################################################################################





plt.xticks(new_df.Wave1[::40])

plt.xlabel('Wavelength')
plt.ylabel('Absorbance')

plt.legend()

# plt.savefig('Gas_price_figure.png', dpi = 300)

plt.show()
