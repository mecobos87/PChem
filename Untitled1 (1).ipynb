# %%
import pandas as pd
import matplotlib.ticker as ticker
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure




new_df = pd.read_csv('Now Pchem lab 2 data.csv')
new_df
# Out:
#          Wave  Abs1  Abs2  Abs3  Abs4  Abs5
# 0     179.802 -0.48  0.00 -0.08  0.41  0.00
# 1     180.182 -0.48  0.00 -0.08  0.41  0.00
# 2     180.563 -0.48  0.00 -0.08  0.41  0.00
# 3     180.943  0.73  0.36  0.19  0.08 -0.01
# 4     181.323  0.00  0.36 -0.42  0.00  0.00
# ...       ...   ...   ...   ...   ...   ...
# 2043  874.673  0.00  0.00 -0.02 -0.02 -0.02
# 2044  874.961  0.01  0.00 -0.02 -0.02 -0.02
# 2045  875.249  0.01  0.00 -0.02 -0.02 -0.02
# 2046  875.538  0.01  0.00 -0.02 -0.02 -0.02
# 2047  875.826  0.01  0.00 -0.02 -0.02 -0.02
#
# [2048 rows x 6 columns]

# %%
plt.figure(figsize= (35,15))

plt.title('UV-Vis Spectroscopy', fontdict = {'fontweight':'bold', 'fontsize': 18})

plt.plot(new_df.Wave, new_df.Abs1, 'b.-', label = 'Carbocyanine')
plt.plot(new_df.Wave, new_df.Abs2, 'g.-', label = 'Cyanine')
plt.plot(new_df.Wave, new_df.Abs3, 'r.-', label = 'Butadiene')
plt.plot(new_df.Wave, new_df.Abs4, 'g.--', label = 'Hexa')
plt.plot(new_df.Wave, new_df.Abs5, 'b.--', label = 'Octa')

#plt.plot(gas.Year, gas.Canada, 'r^-', label = 'Canada')
#plt.plot(gas['Year'], gas['South Korea'], 'g.--', label = 'South Korea')
#plt.plot(gas.Year, gas.Mexico,'.-', label = 'Mexico')

# print(gas.Year[::3])

#####################################################################################################

# for country in gas:
#     if country != 'Year':
#         plt.plot(gas.Year, gas[country], marker = '.', label = country)

#####################################################################################################

# countries_to_see = ['USA', 'Canada', 'South Korea']

# for country in gas:
#     if country in countries_to_see:
#         plt.plot(gas.Year, gas[country], marker = '.', label = country)
        
#####################################################################################################





plt.xticks(new_df.Wave[::40])

plt.xlabel('Wavelength')
plt.ylabel('Absorbance')

plt.legend()

# plt.savefig('Gas_price_figure.png', dpi = 300)

plt.show()
